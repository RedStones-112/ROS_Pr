# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = Image.open("../cv_data/candies.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=380x286>

# %%
image_arr = np.asarray(image)
image_arr.shape
# Out:
# (286, 380, 3)

# %%
plt.imshow(image_arr[:, :, 0])

# %%
plt.imshow(image_arr[:, :, 0], cmap="gray")
